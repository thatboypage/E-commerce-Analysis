# %% [markdown]
# # E-Commerce Analysis
#
# A fast growing e-commerce brand wants to optimize their sales and customer experience.
# This project focuses on uncovering key insights, such as purchasing patterns, peak shopping hours, and payment behaviors.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Analysing E-commerce customer transactions using **Pandas** for Data Manipulation

# %% [markdown]
# ### Step 1: Loading the Dependencies

# %%
import pandas as pd                          # for analysis and data manipulation
import numpy as np                           # for mathematical calculations
import matplotlib.pyplot as plt              # for visualization
import seaborn as sns                        # for visualization
# %matplotlib inline

# %% [markdown]
# ### Step 2: Import the E-commerce Data

# %%
# Loading the Data
df = pd.read_csv('Ecommerce Purchases')
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
# Display the top 5 rows
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
# Display the last five records of the data
df.tail()
# Out:
#                                                 Address    Lot AM or PM  \
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                        Company       Credit Card CC Exp Date  \
# 9995             Randall-Sloan   342945015358701       03/22
# 9996  Hale, Collins and Wilson   210033169205009       07/25
# ...

# %%
# Checking the datatype of each columns
df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
# Checking for null values in the dataset
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# How many rows and colums in the dataset
df.shape
# Out:
# (10000, 14)

# %%
print(f'The dataset has {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# The dataset has 10000 rows and 14 columns

# %% [markdown]
# ### EDA -- Exploratory Data Analysis

# %% [markdown]
# #### What is the highest and lowest price

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
print('Lowest Price', df['Purchase Price'].min())
print('Highest Price', df['Purchase Price'].max())
# Out:
# Lowest Price 0.0
# Highest Price 99.99

# %% [markdown]
# 2. #### What is the highest and lowest price

# %%
print('Average Price', df['Purchase Price'].mean())
# Out:
# Average Price 50.34730200000025

# %%
# Rounding up to 2 decimal places
print('Average Price', round(df['Purchase Price'].mean(),2))
# Out:
# Average Price 50.35

# %%
# Adding a dollar sign
print('Average Price', '$',round(df['Purchase Price'].mean(),2))
# Out:
# Average Price $ 50.35

# %% [markdown]
# #### 3. How many people have French 'Fr' as their language?

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df[df['Language'] == 'fr']
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 53                PSC 9431, Box 7059\nAPO AA 29285-1363  14 qD       AM
# 76    49206 Campbell Port\nNorth Cliffordshire, HI 3...  71 iu       PM
# 82    493 Smith Valleys Suite 004\nNew Madelineville...  35 ls       PM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9951                518 Brown Dam\nGarciaside, IN 33057  71 wq       AM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9980           6061 Dave Lights\nPhillipsview, UT 40500  25 Mv       AM
#
#                                            Browser Info  \
# ...

# %%
print('The total number of people having french as their language is: ', len(df[df['Language'] == 'fr']))
# Out:
# The total number of people having french as their language is:  1097

# %% [markdown]
# #### 4. Job Title that contains Engineer

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df['Job'].str.contains('Engineer', case = False)
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: Job, Length: 10000, dtype: bool

# %%
df[df['Job'].str.contains('Engineer', case = False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
print('The total number of jobs that contains Engineer is: ', len(df[df['Job'].str.contains('Engineer', case = False)]))
# Out:
# The total number of jobs that contains Engineer is:  984

# %% [markdown]
# #### 5.	Find Email of the Person with the following IP Address 132.207.160.22

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df[df['IP Address'] == '132.207.160.22']
# Out:
#                             Address    Lot AM or PM  \
# 2  Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
#
#                                         Browser Info  \
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#                       Company   Credit Card CC Exp Date  CC Security Code  \
# 2  Simpson, Williams and Pham  675957666125       08/19               699
#
#     CC Provider                           Email                       Job  \
# 2  JCB 16 digit  amymiller@morales-harrison.com  Customer service manager
#
#        IP Address Language  Purchase Price
# 2  132.207.160.22       de            0.95

# %%
df[df['IP Address'] == '132.207.160.22'][['Email']]
# Out:
#                             Email
# 2  amymiller@morales-harrison.com

# %% [markdown]
# #### 6.	How many people have master card as their credit card provider and made a purchase above 50

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df['CC Provider']
# Out:
# 0                      JCB 16 digit
# 1                        Mastercard
# 2                      JCB 16 digit
# 3                          Discover
# 4       Diners Club / Carte Blanche
#                    ...
# 9995                   JCB 15 digit
# 9996                   JCB 16 digit
# 9997                  VISA 16 digit
# 9998               American Express
# 9999                   JCB 15 digit
# Name: CC Provider, Length: 10000, dtype: object

# %%
# People that have Mastercard as their Credit Card Provider
df[df['CC Provider'] == 'Mastercard']
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 41    779 Sydney Keys Apt. 119\nAnthonyside, NH 2179...  21 lh       PM
# ...                                                 ...    ...      ...
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
# People that purchased above 50
df[df['Purchase Price'] > 50]
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# ...                                                 ...    ...      ...
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
# Mastercard users that made a purchase above 50
df[(df['CC Provider'] == 'Mastercard') & (df['Purchase Price'] > 50)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# #### 7.Find the email of the person with the following credit card number: 4664825258997302

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
# Locating the person with the credit card number 
df[df['Credit Card'] == 4664825258997302]
# Out:
#                                                 Address    Lot AM or PM  \
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
#
#                                            Browser Info    Company  \
# 9992  Mozilla/5.0 (Macintosh; PPC Mac OS X 10_6_5) A...  Wells Ltd
#
#            Credit Card CC Exp Date  CC Security Code CC Provider  \
# 9992  4664825258997302       10/20               431    Discover
#
#                   Email           Job     IP Address Language  Purchase Price
# 9992  bberry@wright.net  Set designer  174.173.51.32       de           67.96

# %%
# Getting the Email
df[df['Credit Card'] == 4664825258997302][['Email']]
# Out:
#                   Email
# 9992  bberry@wright.net

# %% [markdown]
# #### 8. How many people purchase during the AM and How many people purchase during PM?

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
# Visuaizing AM and PM
sns.countplot(x = 'AM or PM', data = df, color ='blue')
# Out:
# <AxesSubplot:xlabel='AM or PM', ylabel='count'>

# %% [markdown]
# #### 9. How many people have credit card expires in 2020?

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df[df['CC Exp Date'].str.contains('20')]
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 32                     Unit 3628 Box 6778\nDPO AE 72362  39 Qm       PM
# 36    9374 Skinner Common Apt. 254\nChristopherfort,...  80 Fq       PM
# 38    9671 Riley Drives Apt. 746\nPort Davidtown, TN...  15 vj       AM
# ...                                                 ...    ...      ...
# 9883        751 Petersen Groves\nLake Rebecca, NM 55875  61 tE       PM
# 9901      908 Norman Burgs\nPhillipsberg, VT 92023-9956  90 Ng       PM
# 9911  44320 Gray Centers Suite 325\nJenniferfurt, OK...  19 Bf       PM
# 9957             73556 Chase Pine\nBrucemouth, MP 73473  25 rU       PM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
#
#                                            Browser Info  \
# ...

# %%
len(df[df['CC Exp Date'].str.contains('20')])
# Out:
# 988

# %%
print('Total number of people whose CC expires in 2020 is: ', len(df[df['CC Exp Date'].str.contains('20')]))
# Out:
# Total number of people whose CC expires in 2020 is:  988

# %%
# Method 2
df[df['CC Exp Date'].str.split('/', expand = True)[1] == '20']
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 32                     Unit 3628 Box 6778\nDPO AE 72362  39 Qm       PM
# 36    9374 Skinner Common Apt. 254\nChristopherfort,...  80 Fq       PM
# 38    9671 Riley Drives Apt. 746\nPort Davidtown, TN...  15 vj       AM
# ...                                                 ...    ...      ...
# 9883        751 Petersen Groves\nLake Rebecca, NM 55875  61 tE       PM
# 9901      908 Norman Burgs\nPhillipsberg, VT 92023-9956  90 Ng       PM
# 9911  44320 Gray Centers Suite 325\nJenniferfurt, OK...  19 Bf       PM
# 9957             73556 Chase Pine\nBrucemouth, MP 73473  25 rU       PM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# #### 10. Top 5 Most Popular Email provider (e.g. gmail.com, yahoo.com, e t c …)

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
mail = df['Email'].str.split('@', expand = True)[1]
mail
# Out:
# 0                  yahoo.com
# 1                   reed.com
# 2       morales-harrison.com
# 3        olson-robinson.info
# 4                  gmail.com
#                 ...
# 9995         wade-garner.com
# 9996             hotmail.com
# 9997               gmail.com
# 9998                reid.net
# 9999              vaughn.com
# Name: 1, Length: 10000, dtype: object

# %%
mail.value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: 1, dtype: int64

# %% [markdown]
# #### 11. Which Company has the highest purchasing price

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df['Company']
# Out:
# 0                       Martinez-Herman
# 1       Fletcher, Richards and Whitaker
# 2            Simpson, Williams and Pham
# 3       Williams, Marshall and Buchanan
# 4             Brown, Watson and Andrews
#                      ...
# 9995                      Randall-Sloan
# 9996           Hale, Collins and Wilson
# 9997                       Anderson Ltd
# 9998                           Cook Inc
# 9999                         Greene Inc
# Name: Company, Length: 10000, dtype: object

# %%
df['Company'].value_counts()
# Out:
# Brown Ltd                   15
# Smith Group                 15
# Smith PLC                   13
# Smith LLC                   13
# Williams LLC                12
#                             ..
# Hughes, Wyatt and Larson     1
# Velez Inc                    1
# Miller-Jacobs                1
# Davis, Parker and Rivera     1
# Greene Inc                   1
# Name: Company, Length: 8653, dtype: int64

# %%
# Showing the highest purchase price by company
df.groupby('Company')['Purchase Price'].sum()
# Out:
# Company
# Abbott Ltd                   77.45
# Abbott and Sons              66.18
# Abbott-Johnson               91.06
# Acevedo PLC                  37.38
# Acevedo, Nguyen and Moore     7.36
#                              ...
# Zimmerman-Woodard            68.77
# Zuniga, Cooper and Smith     29.39
# Zuniga, Morris and Smith     34.43
# Zuniga-Fowler                72.72
# Zuniga-Watson                 0.32
# Name: Purchase Price, Length: 8653, dtype: float64

# %%
purchase_price_by_company = df.groupby('Company')['Purchase Price'].sum()
purchase_price_by_company = purchase_price_by_company.sort_values(ascending = False)
# Out:
# Company
# Brown Ltd                796.38
# Williams LLC             723.63
# Smith LLC                637.92
# Smith PLC                601.37
# Johnson Ltd              600.61
#                           ...
# Washington-Johnson         0.03
# Armstrong PLC              0.02
# Sanchez-Stephenson         0.01
# Lyons, Diaz and Clark      0.00
# Flynn and Sons             0.00
# Name: Purchase Price, Length: 8653, dtype: float64

# %%
purchase_price_by_company.head()
# Out:
# Company
# Abbott Ltd                   77.45
# Abbott and Sons              66.18
# Abbott-Johnson               91.06
# Acevedo PLC                  37.38
# Acevedo, Nguyen and Moore     7.36
# Name: Purchase Price, dtype: float64
